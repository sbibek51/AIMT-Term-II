# %%
#Bibek Shiwakoti

# %%
import pandas as pd

# %%
df1= pd.read_csv('../data/class_4_data (1).csv')
df2= pd.read_csv('../data/class_4_df_dev (2).csv')

# %%
df1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df1.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df2.head()
# Out:
#       ID  credit_limit card_type  gender  education  age  pay_status_1  \
# 0  10000        310000      VISA       1          3   32             0
# 1  10001         10000       NaN       2          3   49            -1
# 2  10002         50000    MASTER       1          2   30            -1
# 3  10003         80000      VISA       2          3   52             2
# 4  10004        270000       NaN       1          1   36             1
#
#    pay_status_2  pay_status_3  pay_status_4  ...  bill_amount_2  \
# 0             0             0             0  ...         152397
# 1            -1            -2            -1  ...           -358
# 2            -1            -1             0  ...              0
# 3             2             3             3  ...          39448
# 4             2             0             0  ...          17228
#
#    bill_amount_3  bill_amount_4  bill_amount_5  pay_amount_1  pay_amount_2  \
# ...

# %%
df2.tail()
# Out:
#           ID  credit_limit card_type  gender  education  age  pay_status_1  \
# 19995  29995        310000      VISA       2          1   45             0
# 19996  29996         90000    MASTER       2          2   25            -1
# 19997  29997        100000      VISA       2          2   23             0
# 19998  29998        170000      VISA       2          2   27            -1
# 19999  29999         30000       NaN       2          3   24            -1
#
#        pay_status_2  pay_status_3  pay_status_4  ...  bill_amount_2  \
# 19995             0             0             0  ...          93351
# 19996            -1            -1            -1  ...           4300
# 19997             0             0             0  ...           7954
# 19998            -1            -1             0  ...          -1020
# 19999            -1             0            -1  ...          29393
#
#        bill_amount_3  bill_amount_4  bill_amount_5  pay_amount_1  \
# ...

# %% [markdown]
# ## Let us work on first dataset in this section

# %%
df1.info()  #looking at the info of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df1.columns #Looking at the coloumns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df1.shape[0] #looking at the number of rows
# Out:
# 1460

# %%
# Identify and separate categorical and numerical columns
categorical_columns = df1.select_dtypes(include=['object']).columns
numerical_columns = df1.select_dtypes(exclude=['object']).columns

# Print the categorical columns
print("Categorical columns:")
print(categorical_columns)

# Print the numeric columns
print("Numeric columns:")
print(numerical_columns)
# Out:
# Categorical columns:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')
# Numeric columns:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
# ...

# %%
df1.shape [1] #looking at the number of columns
# Out:
# 81

# %%
df1.isnull().sum().sort_values(ascending=False) #looking at the null values in ascending order
# Out:
# PoolQC         1453
# MiscFeature    1406
# Alley          1369
# Fence          1179
# FireplaceQu     690
#                ...
# ExterQual         0
# Exterior2nd       0
# Exterior1st       0
# RoofMatl          0
# SalePrice         0
# Length: 81, dtype: int64

# %%
df1.notna().sum().sort_values(ascending=False)  #looking at not null values
# Out:
# Id              1460
# GrLivArea       1460
# KitchenAbvGr    1460
# BedroomAbvGr    1460
# HalfBath        1460
#                 ...
# FireplaceQu      770
# Fence            281
# Alley             91
# MiscFeature       54
# PoolQC             7
# Length: 81, dtype: int64

# %%
df1.isnull().mean()  ##looking at the ratio of null values
# Out:
# Id               0.000000
# MSSubClass       0.000000
# MSZoning         0.000000
# LotFrontage      0.177397
# LotArea          0.000000
#                    ...
# MoSold           0.000000
# YrSold           0.000000
# SaleType         0.000000
# SaleCondition    0.000000
# SalePrice        0.000000
# Length: 81, dtype: float64

# %%
df1.dtypes  #looking at the data types of each columns
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df1.select_dtypes(include=['float64'])
# Out:
#       LotFrontage  MasVnrArea  GarageYrBlt
# 0            65.0       196.0       2003.0
# 1            80.0         0.0       1976.0
# 2            68.0       162.0       2001.0
# 3            60.0         0.0       1998.0
# 4            84.0       350.0       2000.0
# ...           ...         ...          ...
# 1455         62.0         0.0       1999.0
# 1456         85.0       119.0       1978.0
# 1457         66.0         0.0       1941.0
# 1458         68.0         0.0       1950.0
# 1459         75.0         0.0       1965.0
#
# [1460 rows x 3 columns]

# %%
df1.select_dtypes(exclude=['int64'])
# Out:
#      MSZoning  LotFrontage Street Alley LotShape LandContour Utilities  \
# 0          RL         65.0   Pave   NaN      Reg         Lvl    AllPub
# 1          RL         80.0   Pave   NaN      Reg         Lvl    AllPub
# 2          RL         68.0   Pave   NaN      IR1         Lvl    AllPub
# 3          RL         60.0   Pave   NaN      IR1         Lvl    AllPub
# 4          RL         84.0   Pave   NaN      IR1         Lvl    AllPub
# ...       ...          ...    ...   ...      ...         ...       ...
# 1455       RL         62.0   Pave   NaN      Reg         Lvl    AllPub
# 1456       RL         85.0   Pave   NaN      Reg         Lvl    AllPub
# 1457       RL         66.0   Pave   NaN      Reg         Lvl    AllPub
# 1458       RL         68.0   Pave   NaN      Reg         Lvl    AllPub
# 1459       RL         75.0   Pave   NaN      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... GarageYrBlt GarageFinish  \
# ...

# %%
# checking the target variable SalesCondition
df1["SaleCondition"].describe()
# Out:
# count       1460
# unique         6
# top       Normal
# freq        1198
# Name: SaleCondition, dtype: object

# %%
# filtering example implement
filtered_df = df1[(df1['LotConfig'] == 'Inside') & (df1['LotFrontage'] > 70)]

# Displaying the filtered result
print("Filtered dataset with Lotconfif Inside and Lotfrontage greater than 70:")
print(filtered_df)
# Out:
# Filtered dataset for houses with 'Electrical' with more than 3 BedroomAbvGr:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# ...

# %% [markdown]
# ## Implementing the concepts from class 4

# %%
#looking at the column Roofstyle unique values only
df1['RoofStyle'].unique()
# Out:
# array(['Gable', 'Hip', 'Gambrel', 'Mansard', 'Flat', 'Shed'], dtype=object)

# %%
df1['LotFrontage'].nlargest(10)
# Out:
# 934     313.0
# 1298    313.0
# 1127    182.0
# 197     174.0
# 231     174.0
# 1107    168.0
# 1182    160.0
# 1337    153.0
# 1211    152.0
# 313     150.0
# Name: LotFrontage, dtype: float64

# %%
df1['GarageYrBlt'].mean()
# Out:
# 1978.5061638868744

# %%
df1['LotShape'].value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
df1['Neighborhood'].value_counts()
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %%
df1['Neighborhood'].value_counts().loc['Mitchel']
# Out:
# 49

# %%
df1['Neighborhood'].value_counts(normalize=True).head()
# Out:
# NAmes      0.154110
# CollgCr    0.102740
# OldTown    0.077397
# Edwards    0.068493
# Somerst    0.058904
# Name: Neighborhood, dtype: float64

# %%
df1['LotShape'].value_counts(normalize=True).head()
# Out:
# Reg    0.633562
# IR1    0.331507
# IR2    0.028082
# IR3    0.006849
# Name: LotShape, dtype: float64

# %%
df1['LotShape'].value_counts().loc['IR2']
# Out:
# 41

# %%
#Grouping
lot_shape_grp = df1.groupby('LotShape')

# %%
lot_shape_grp

# %%
df1[df1['LotShape']=='IR3'] #looking at the lotshape having the value of IR3 form the group of Lotshape
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 264    265          30       RM         30.0     5232   Pave  Grvl      IR3
# 301    302          60       RL         66.0    16226   Pave   NaN      IR3
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
# 1006  1007          20       RL          NaN    12155   Pave   NaN      IR3
# 1107  1108          60       RL        168.0    23257   Pave   NaN      IR3
# 1127  1128          20       RL        182.0    14572   Pave   NaN      IR3
# 1260  1261          60       RL          NaN    24682   Pave   NaN      IR3
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1348  1349          20       RL          NaN    16196   Pave   NaN      IR3
# 1430  1431          60       RL         60.0    21930   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# ...

# %%
list(df1.columns)
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %%
lot_shape_grp['LotShape'].value_counts()
# Out:
# LotShape  LotShape
# IR1       IR1         484
# IR2       IR2          41
# IR3       IR3          10
# Reg       Reg         925
# Name: LotShape, dtype: int64

# %%
#using the concepts of apply in the group
df1[df1['LandContour'].str.contains('Bnk',na=False)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 21      22          45       RM         57.0     7449   Pave  Grvl      Reg
# 52      53          90       RM        110.0     8472   Grvl   NaN      IR2
# 54      55          80       RL         60.0     7134   Pave   NaN      Reg
# 59      60          20       RL         60.0     7200   Pave   NaN      Reg
# 63      64          70       RM         50.0    10300   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1376  1377          30       RL         52.0     6292   Pave   NaN      Reg
# 1396  1397          20       RL          NaN    57200   Pave   NaN      IR1
# 1414  1415          50       RL         64.0    13053   Pave  Pave      Reg
# 1427  1428          50       RL         60.0    10930   Pave  Grvl      Reg
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
#
# ...

# %%
# https://machinelearningmastery.com/feature-selection-with-real-and-categorical-data/

# have to implement the feature selection code from the given link by professor

# %%
#have to apply feature selection on the this and another dataset too in home
